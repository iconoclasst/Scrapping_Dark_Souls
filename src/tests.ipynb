# %%
import pandas as pd
import scrap

# %%
daggers = scrap.get_daggers()

# %%
daggers
# Out:
# [['Icon',
#   'Name',
#   'Damage',
#   'Critical Bonus',
#   'Durability',
#   'Weight',
#   'Stats Needed\nStat Bonuses',
#   'Availability',
#   'Special Note'],
#  ["Bandit's Knife",
#   'Dagger',
#   'Dark Silver Tracer',
#   'Ghost Blade',
#   'Parrying Dagger',
#   "Priscilla's Dagger"],
#  ['56/0/0/0 Bleed 300 (Slashing)',
#   '56/0/0/0 (Slashing/Thrust)',
#   '75/0/0/0 (Slashing/Thrust)',
#   '110/0/0/0 (Slashing/Thrust)',
#   '54/0/0/0 (Slashing/Thrust)',
#   '80/0/0/0 Bleed 500 Dark 110 (Slashing/Thrust)'],
#  ['147', '131', '160', '127', '131', '100'],
#  ['200', '200', '120', '100', '200', '100']]

# %%
columns = daggers.pop(0)
columns
# Out:
# ['Icon',
#  'Name',
#  'Damage',
#  'Critical Bonus',
#  'Durability',
#  'Weight',
#  'Stats Needed\nStat Bonuses',
#  'Availability',
#  'Special Note']

# %%
columns.pop(0)
for i in range(3):
    columns.pop(5)
columns.pop(4)
# Out:
# 'Weight'

# %%
columns
# Out:
# ['Name', 'Damage', 'Critical Bonus', 'Durability']

# %%
daggers
# Out:
# [["Bandit's Knife",
#   'Dagger',
#   'Dark Silver Tracer',
#   'Ghost Blade',
#   'Parrying Dagger',
#   "Priscilla's Dagger"],
#  ['56/0/0/0 Bleed 300 (Slashing)',
#   '56/0/0/0 (Slashing/Thrust)',
#   '75/0/0/0 (Slashing/Thrust)',
#   '110/0/0/0 (Slashing/Thrust)',
#   '54/0/0/0 (Slashing/Thrust)',
#   '80/0/0/0 Bleed 500 Dark 110 (Slashing/Thrust)'],
#  ['147', '131', '160', '127', '131', '100'],
#  ['200', '200', '120', '100', '200', '100']]

# %%
df = pd.DataFrame(daggers)

# %%
df = df.T

# %%
df
# Out:
#                     0                                              1    2    3
# 0      Bandit's Knife                  56/0/0/0 Bleed 300 (Slashing)  147  200
# 1              Dagger                     56/0/0/0 (Slashing/Thrust)  131  200
# 2  Dark Silver Tracer                     75/0/0/0 (Slashing/Thrust)  160  120
# 3         Ghost Blade                    110/0/0/0 (Slashing/Thrust)  127  100
# 4     Parrying Dagger                     54/0/0/0 (Slashing/Thrust)  131  200
# 5  Priscilla's Dagger  80/0/0/0 Bleed 500 Dark 110 (Slashing/Thrust)  100  100

# %%
df.
# Out:
#                                0                           1  \
# 0                 Bandit's Knife                      Dagger
# 1  56/0/0/0 Bleed 300 (Slashing)  56/0/0/0 (Slashing/Thrust)
# 2                            147                         131
# 3                            200                         200
#
#                             2                            3  \
# 0          Dark Silver Tracer                  Ghost Blade
# 1  75/0/0/0 (Slashing/Thrust)  110/0/0/0 (Slashing/Thrust)
# 2                         160                          127
# 3                         120                          100
#
#                             4                                              5
# 0             Parrying Dagger                             Priscilla's Dagger
# 1  54/0/0/0 (Slashing/Thrust)  80/0/0/0 Bleed 500 Dark 110 (Slashing/Thrust)
# 2                         131                                            100
# ...
