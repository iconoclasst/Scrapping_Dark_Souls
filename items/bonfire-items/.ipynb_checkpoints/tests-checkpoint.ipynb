# %%
import pandas as pd
import scrap
# Out:
# {'name': ['Armor Smithbox', 'Bottomless Box', 'Lordvessel', 'Repairbox', 'Rite of Kindling', 'Weapon Smithbox'], 'availability': ['Sold by Andre of Astora for 2000 souls. Sold by Vamos for 2000 souls. Sold by Giant Blacksmith for 2000 souls.', 'Sold by Undead Merchant for 1000 souls. Sold by Domhnall of Zena for 1000 souls.', 'Given to the player by Gwynevere, Princess of Sunlight after defeating Dragonslayer Ornstein and Executioner Smough in Anor Londo .', 'Sold by Undead Merchant for 3000 souls. Sold by Andre of Astora for 2000 souls. Sold by Vamos for 2000 souls. Sold by Giant Blacksmith for 2000 souls.', 'Obtained after defeating Pinwheel in the The Catacombs .', 'Sold by Andre of Astora for 2000 souls. Sold by Vamos for 2000 souls. Sold by Giant Blacksmith for 2000 souls.'], 'use': ['Allows to reinforce any piece of armor at a bonfire given they have the titanite and souls to do so.', 'Allows inventory management at a bonfire.', 'Allows player to quick travel to specific bonfir
# ...

# %%
bonfire_items = scrap.get_bonfire_items()

# %%
bonfire_items = pd.DataFrame(bonfire_items)

# %%
bonfire_items
# Out:
#                name                                       availability  \
# 0    Armor Smithbox  Sold by Andre of Astora for 2000 souls. Sold b...
# 1    Bottomless Box  Sold by Undead Merchant for 1000 souls. Sold b...
# 2        Lordvessel  Given to the player by Gwynevere, Princess of ...
# 3         Repairbox  Sold by Undead Merchant for 3000 souls. Sold b...
# 4  Rite of Kindling  Obtained after defeating Pinwheel in the The C...
# 5   Weapon Smithbox  Sold by Andre of Astora for 2000 souls. Sold b...
#
#                                                  use  \
# 0  Allows to reinforce any piece of armor at a bo...
# 1          Allows inventory management at a bonfire.
# 2  Allows player to quick travel to specific bonf...
# 3  Allows player to repair any equipment at a bon...
# 4          Allows maximum reinforcement of Bonfires.
# 5  Allows to reinforce any weapon at a bonfire gi...
#
#                                         special note
# ...
