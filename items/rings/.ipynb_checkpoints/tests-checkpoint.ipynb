# %%
import pandas as pd
import scrap

# %%
rings = scrap.get_rings()

# %%
rings = pd.DataFrame(rings)

# %%
rings
# Out:
#                             name  \
# 0     Bellowing Dragoncrest Ring
# 1                 Bloodbite Ring
# 2            Blue Tearstone Ring
# 3                  Calamity Ring
# 4              Cat Covenant Ring
# 5                 Cloranthy Ring
# 6           Covenant Of Artorias
# 7     Covetous Gold Serpent Ring
# 8   Covetous Silver Serpent Ring
# 9                 Cursebite Ring
# 10  Darkmoon Blade Covenant Ring
# 11          Darkmoon Seance Ring
# 12          Dark Wood Grain Ring
# 13               Dusk Crown Ring
# 14          East Wood Grain Ring
# 15         Flame Stoneplate Ring
# 16                  Havel's Ring
# 17                     Hawk Ring
# 18                   Hornet Ring
# 19                      Leo Ring
# 20    Lingering Dragoncrest Ring
# 21              Old Witch's Ring
# 22           Orange Charred Ring
# 23               Poisonbite Ring
# 24        Rare Ring of Sacrifice
# 25            Red Tearstone Ring
# 26  Ring of Favor and Protection
# ...
