# %%
import pandas as pd
import scrap

# %%
keys = scrap.get_keys()

# %%
keys = pd.DataFrame(keys)

# %%
keys
# Out:
#                             name  \
# 0                      Annex Key
# 1         Archive Tower Cell Key
# 2   Archive Tower Giant Cell Key
# 3   Archive Tower Giant Door Key
# 4       Archive Prison Extra Key
# 5                   Basement Key
# 6              Big Pilgrim´s Key
# 7                 Blighttown Key
# 8                 Broken Pendant
# 9                       Cage Key
# 10                     Crest Key
# 11             Crest of Artorias
# 12              Dungeon Cell Key
# 13        Key to New Londo Ruins
# 14             Key to the Depths
# 15               Key to the Seal
# 16                    Master Key
# 17                   Mystery Key
# 18                 Peculiar Doll
# 19                 Residence Key
# 20     Undead Asylum F2 East Key
# 21     Undead Asylum F2 West Key
# 22             Sewer Chamber Key
# 23       Watchtower Basement Key
#
#                                          availability  \
# 0                            Painted World of Ariamis
# ...
