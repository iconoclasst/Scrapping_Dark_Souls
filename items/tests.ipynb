# %%
import pandas as pd
import scrap

# %%
spell_tools = scrap.get_spell_tools()

# %%
df_spell_tools = pd.DataFrame(spell_tools)

# %%
df_spell_tools
# Out:
#                             name magic adjustment                damage  \
# 0            Beatrice's Catalyst              240     40/0/0/0 (Strike)
# 1               Demon's Catalyst              200  110/0/170/0 (Thrust)
# 2               Izalith Catalyst              240     40/0/0/0 (Strike)
# 3               Logan's Catalyst              250     46/0/0/0 (Strike)
# 4                 Manus Catalyst              295    190/0/0/0 (Strike)
# 5              Oolacile Catalyst              180     40/0/0/0 (Strike)
# 6        Oolacile Ivory Catalyst              180     24/0/0/0 (Strike)
# 7            Sorcerer's Catalyst              240     40/0/0/0 (Strike)
# 8        Tin Banishment Catalyst              220    145/0/0/0 (Thrust)
# 9   Tin Crystallization Catalyst              315    240/0/0/0 (Thrust)
# 10         Tin Darkmoon Catalyst              230     44/0/0/0 (Strike)
# 11               Canvas Talisman              220     14/0/0/0 (Strike)
# ...
