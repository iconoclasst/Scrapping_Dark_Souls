# %%
import pandas as pd
import scrap

# %%
consumables = scrap.get_consumables()

# %%
consumables = pd.DataFrame(consumables)

# %%
consumables
# Out:
#                                 name  \
# 0                        Estus Flask
# 1               Elizabeth's Mushroom
# 2                Bloodred Moss Clump
# 3                  Purple Moss Clump
# 4         Blooming Purple Moss Clump
# 5                    Divine Blessing
# 6                      Egg Vermifuge
# 7                      Green Blossom
# 8                      Purging Stone
# 9                           Firebomb
# 10                    Black Firebomb
# 11                          Dung pie
# 12                    Throwing Knife
# 13             Poison Throwing Knife
# 14               Charcoal Pine Resin
# 15                   Gold Pine Resin
# 16                 Rotten Pine Resin
# 17                  Fire Keeper Soul
# 18             Soul of a Lost Undead
# 19       Large Soul of a Lost Undead
# 20        Soul of a Nameless Soldier
# 21  Large Soul of a Nameless Soldier
# 22            Soul of a Proud Knight
# 23      Large Soul of a Proud Knight
# ...
