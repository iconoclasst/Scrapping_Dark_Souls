# %%
import pandas as pd
import scrap

# %%
multiplayer_items = scrap.get_multiplayer_items()

# %%
multiplayer_items = pd.DataFrame(multiplayer_items)

# %%
multiplayer_items
# Out:
#                          name  \
# 0    Black Separation Crystal
# 1   Orange Guidance Soapstone
# 2     Purple Coward's Crystal
# 3          Red Sign Soapstone
# 4        White Sign Soapstone
# 5               Black Eye Orb
# 6                Blue Eye Orb
# 7         Cracked Red Eye Orb
# 8                 Red Eye Orb
# 9                  Dragon Eye
# 10          Dragon Head Stone
# 11         Dragon Torso Stone
# 12               Eye of Death
# 13       Souvenir of Reprisal
# 14             Sunlight Medal
# 15              Hello Carving
# 16         Very Good! Carving
# 17          Thank You Carving
# 18          I'm Sorry Carving
# 19           Help Me! Carving
# 20         Book of the Guilty
# 21               Dried Finger
# 22                 Indictment
# 23             Servant Roster
#
#                                                   use  \
# 0   Host can banish any friendly Phantoms or Phant...
# 1                                 Write/Rate messages
# ...
