# %%
import pandas as pd
import scrap

# %%
ammo = scrap.get_ammo()

# %%
ammo = pd.DataFrame(ammo)

# %%
ammo
# Out:
#                    name              damage bow dist rate bonus  \
# 0          Wooden Arrow   35/0/0/0 (Thrust)                  20
# 1        Standard Arrow   45/0/0/0 (Thrust)                  20
# 2           Large Arrow   60/0/0/0 (Thrust)                  15
# 3         Feather Arrow   50/0/0/0 (Thrust)                  25
# 4            Fire Arrow  35/0/50/0 (Thrust)                  20
# 5          Poison Arrow   42/0/0/0 (Thrust)                  20
# 6       Moonlight Arrow   0/80/0/0 (Thrust)                  20
# 7    Dragonslayer Arrow  100/0/0/0 (Thrust)                  30
# 8   Gough's Great Arrow  105/0/0/0 (Thrust)                  25
# 9             Wood Bolt   38/0/0/0 (Thrust)                  20
# 10        Standard Bolt   48/0/0/0 (Thrust)                  20
# 11           Heavy Bolt   64/0/0/0 (Thrust)                  15
# 12       Lightning Bolt  38/0/0/78 (Thrust)                  20
# 13          Sniper Bolt   53/0/0/0 (Thrust)                  25
#
# ...
