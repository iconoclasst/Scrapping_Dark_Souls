# %%
import pandas as pd
import scrap

# %%
shields = scrap.get_shields()

# %%
df_shields = pd.DataFrame(shields)

# %%
df_shields
# Out:
#                           name damage reduction stability (max) durability  \
# 0                      Buckler      76/32/65/53         40 (50)        140
# 1        Caduceus Round Shield      85/65/30/65         40 (50)        180
# 2         Cracked Round Shield      65/55/10/45         30 (37)         60
# 3                Effigy Shield      90/40/70/90         45 (56)        180
# 4               Leather Shield      85/35/60/60         45 (56)        200
# 5                 Plank Shield      75/40/20/55         45 (56)        120
# 6   Red and white round shield      85/65/30/64         40 (50)        180
# 7         Small Leather Shield      80/35/60/60         40 (50)        200
# 8                Target Shield      78/30/65/50         45 (56)        150
# 9       Warrior's Round Shield      85/65/30/65         40 (50)        180
# 10               Balder Shield     100/20/60/50         63 (75)        220
# ...
