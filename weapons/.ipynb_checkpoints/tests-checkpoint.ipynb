# %%
import pandas as pd
import scrap

# %%
weapons = scrap.get_weapons()

# %%
df_weapons = pd.DataFrame(weapons)

# %%
df_weapons
# Out:
#                        name               damage critical durability weight  \
# 0                      Fist    20/0/0/0 (Strike)     None          5      0
# 1                   Caestus    66/0/0/0 (Strike)     None        300    0.5
# 2                      Claw     72/0/0/0 (Slash)     None        150    1.0
# 3    Dark Hand (Right Hand)   200/0/0/0 (Strike)     None        999    0.5
# 4          Dragon Bone Fist    90/0/0/0 (Strike)     None        999    8.0
# ..                      ...                  ...      ...        ...    ...
# 115   Dragonslayer Greatbow    90/0/0/0 (Normal)       50        100   10.0
# 116        Gough's Greatbow    85/0/0/0 (Normal)       55        100   13.0
# 117           Guardian Tail  84/0/0/0 Poison 300     None        250    5.0
# 118            Notched Whip   76/0/0/0 Bleed 300     None        200    2.0
# 119                    Whip    80/0/0/0 (Normal)     None        200    1.5
#
# ...
